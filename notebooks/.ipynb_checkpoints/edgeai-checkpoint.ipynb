# %%
from comet_ml import Experiment
import json

# %%
import os
os.listdir("/glock/gun/notebooks/")
# Out:
# ['unity2coco.ipynb',
#  'create_coco_glock_dataset.ipynb',
#  'Dockerfile',
#  'coco_from_edge.ipynb',
#  'coco_from_aws.ipynb',
#  'api_key.txt',
#  'detectron_glock.ipynb',
#  '.ipynb_checkpoints',
#  'edgeai.ipynb']

# %%
with open("/glock/gun/notebooks/api_key.txt", "r") as f:
    api_key = json.load(f)
    print("opened")
# Out:
# opened

# %%
hyper_params = {
    "learning_rate": 0.001,
    "IMS_PER_BATCH": 4,
    "GAMMA" : 0.8,
    "FREEZE_AT" : 1,
    'IMS_PER_BATCH' : 4,
    "WARMUP_ITERS" : 10000,
    'SOLVER_STEPS':(40000, 80000, 120000, 200000, 500000)
}

experiment = Experiment(project_name="gun", api_key=api_key['api_key'])
experiment.log_parameters(hyper_params)
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/michalmiotk/gun/395a9d288bd24f02a2e75dd7e5a9b579

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("weapons", {}, "/Pobrane/trainval.json", "/Pobrane/images")
register_coco_instances("weapons_test", {}, "/Pobrane/trainval.json", "/Pobrane/images")
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 1000000})

# %%
from detectron2.data import MetadataCatalog
from detectron2.data import DatasetCatalog

# %%
dataset_dicts = DatasetCatalog.get("weapons")
glock_metadata = MetadataCatalog.get("weapons")

# %%
import matplotlib.pyplot as plt
import random
from detectron2.utils.visualizer import Visualizer
import cv2

# %%
for d in random.sample(dataset_dicts, 1):
    img = cv2.imread(d["file_name"])
    print(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=glock_metadata, scale=1)
    vis = visualizer.draw_dataset_dict(d)
    plt.figure()
    plt.imshow(vis.get_image())
# Out:
# /Pobrane/images/More-weapons-1/table_31267_original.png

# %%
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor

# %%
from datetime import datetime
import os

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
# cfg.OUTPUT_DIR = "tboard_logs/test_test_2020-02-22T23:14/"
cfg.OUTPUT_DIR = f"/glock/tboard_logs/weapons"#_{datetime.now().isoformat().rsplit(':', 1)[0]}/"

cfg.DATASETS.TRAIN = ("weapons",)
cfg.DATASETS.TEST = ("weapons_test",)
cfg.DATALOADER.NUM_WORKERS = 4

# cfg.INPUT.FORMAT = "RGB"
cfg.INPUT.FORMAT = "BGR"

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.MODEL.RETINANET.NUM_CLASSES = 2
cfg.MODEL.BACKBONE.FREEZE_AT=hyper_params['FREEZE_AT']
# cfg.MODEL.PIXEL_MEAN = [103.53, 116.28, 123.675, 187.153] #ostatnia wartość wpisana z palca
cfg.MODEL.PIXEL_STD =  [1.0, 1.0, 1.0]#, 1.0]
cfg.MODEL.PIXEL_MEAN = [68.60176277048289, 90.37255792238817, 99.04053918695983][::-1]
#, 187.12327778336686]
# cfg.MODEL.PIXEL_STD = [25.05072945688351, 22.96708310183466, 13.27640256812483, 10.55706656507702]


cfg.SOLVER.IMS_PER_BATCH = hyper_params['IMS_PER_BATCH'] # 32
cfg.SOLVER.BASE_LR = hyper_params['learning_rate'] # 0.0001  # pick a good LR
cfg.SOLVER.MAX_ITER = 500_000  # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical data

cfg.SOLVER.WARMUP_ITERS =  hyper_params['WARMUP_ITERS']
cfg.SOLVER.GAMMA = hyper_params['GAMMA']
cfg.SOLVER.STEPS = hyper_params['SOLVER_STEPS']

cfg.SOLVER.CHECKPOINT_PERIOD = 4000


# cfg.MODEL.RETINANET.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)

cfg.TEST.EVAL_PERIOD = 100000_000 
cfg.TEST.DETECTIONS_PER_IMAGE = 10

cfg.VIS_PERIOD = 10000

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
with open("/glock/gun/config.yml", "w") as f:
    f.write(cfg.dump())

# %%
from detectron2.engine.hooks import HookBase
from detectron2.evaluation import inference_context
from detectron2.utils.logger import log_every_n_seconds
from detectron2.data import DatasetMapper, build_detection_test_loader
import detectron2.utils.comm as comm
import torch
import time
import datetime

class LossEvalHook(HookBase):
    def __init__(self, eval_period, model, data_loader):
        self._model = model
        self._period = eval_period
        self._data_loader = data_loader
    
    def _do_loss_eval(self):
        # Copying inference_on_dataset from evaluator.py
        total = len(self._data_loader)
        num_warmup = min(5, total - 1)
            
        start_time = time.perf_counter()
        total_compute_time = 0
        losses = []
        for idx, inputs in enumerate(self._data_loader):            
            if idx == num_warmup:
                start_time = time.perf_counter()
                total_compute_time = 0
            start_compute_time = time.perf_counter()
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            total_compute_time += time.perf_counter() - start_compute_time
            iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
            seconds_per_img = total_compute_time / iters_after_start
            if idx >= num_warmup * 2 or seconds_per_img > 5:
                total_seconds_per_img = (time.perf_counter() - start_time) / iters_after_start
                eta = datetime.timedelta(seconds=int(total_seconds_per_img * (total - idx - 1)))
                log_every_n_seconds(
                    logging.INFO,
                    "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                        idx + 1, total, seconds_per_img, str(eta)
                    ),
                    n=5,
                )
            loss_batch = self._get_loss(inputs)
            losses.append(loss_batch)
        mean_loss = np.mean(losses)
        self.trainer.storage.put_scalar('validation_loss', mean_loss)
        comm.synchronize()

        return losses
            
    def _get_loss(self, data):
        # How loss is calculated on train_loop 
        metrics_dict = self._model(data)
        metrics_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in metrics_dict.items()
        }
        total_losses_reduced = sum(loss for loss in metrics_dict.values())
        return total_losses_reduced
        
        
    def after_step(self):
        next_iter = self.trainer.iter + 1
        is_final = next_iter == self.trainer.max_iter
        if is_final or (self._period > 0 and next_iter % self._period == 0):
            self._do_loss_eval()
        self.trainer.storage.put_scalars(timetest=12)

# %%
class MyTrainer(DefaultTrainer):
    
view raw

# %%
https://medium.com/@apofeniaco/training-on-detectron2-with-a-validation-set-and-plot-loss-on-it-to-avoid-overfitting-6449418fbf4e

# %%
from detectron2.evaluation.coco_evaluation import COCOEvaluator
from detectron2.data import DatasetMapper
import detectron2.data.transforms as T
from detectron2.data import build_detection_train_loader
def build_sem_seg_train_aug(cfg):
    augs = [
        T.ResizeShortestEdge(
            cfg.INPUT.MIN_SIZE_TRAIN, cfg.INPUT.MAX_SIZE_TRAIN, cfg.INPUT.MIN_SIZE_TRAIN_SAMPLING
        )
    ]
    if cfg.INPUT.CROP.ENABLED:
        augs.append(
            T.RandomCrop_CategoryAreaConstraint(
                cfg.INPUT.CROP.TYPE,
                cfg.INPUT.CROP.SIZE,
                cfg.INPUT.CROP.SINGLE_CATEGORY_MAX_AREA,
            )
        )
    augs.append(T.RandomFlip())
    return augs
class Trainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        return COCOEvaluator('glock_test', cfg, False)
    
    @classmethod
    def build_train_loader(cls, cfg):
        mapper = DatasetMapper(cfg, is_train=True, augmentations=build_sem_seg_train_aug(cfg))
        return build_detection_train_loader(cfg, mapper=mapper)
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        return COCOEvaluator(dataset_name, cfg, True, output_folder)
                     
    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(-1,LossEvalHook(
            cfg.TEST.EVAL_PERIOD,
            self.model,
            build_detection_test_loader(
                self.cfg,
                self.cfg.DATASETS.TEST[0],
                DatasetMapper(self.cfg,True)
            )
        ))
        return hooks
trainer = Trainer(cfg)
trainer.resume_or_load(resume=True)
trainer.train()
# Out:
# [11/03 21:45:57 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten()
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [11/03 21:45:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [11/03 21:46:08 d2.data.datasets.coco]: Loading /Pobrane/trainval.json takes 10.56 seconds.
# [11/03 21:46:08 d2.data.datasets.coco]: Loaded 69988 images in COCO format from /Pobrane/trainval.json
# [11/03 21:46:11 d2.data.build]: Removed 0 images with no usable annotations. 69988 images left.
# [11/03 21:46:13 d2.data.common]: Serializing 69988 elements to byte tensors and concatenating them all ...
# [11/03 21:46:14 d2.data.common]: Serialized dataset takes 269.91 MiB
# [11/03 21:46:14 d2.data.build]: Using training sampler TrainingSampler
# [11/03 21:46:15 d2.engine.train_loop]: Starting training from iteration 100000
# [11/03 21:46:23 d2.utils.events]:  eta: 1 day, 15:39:26  iter: 100019  total_loss: 0.366  loss_cls: 0.04979  loss_box_reg: 0.07848  loss_mask: 0.1618  loss_rpn_cls: 0.01887  loss_rpn_loc: 0.04906  time: 0.3585  data_time: 0.0223  lr: 3e-05  max_mem: 3325M
# [11/03 21:46:31 d2.utils.events]:  eta: 1 day, 14:31:59  iter: 100039  total_loss: 0.5464  loss_cls: 0.07635  loss_box_reg: 0.1019  loss_mask: 0.1876  loss_rpn_cls: 0.02478  loss_rpn_loc: 0.1164  time: 0.3490  data_time: 0.0174  lr: 3e-05  max_mem: 3325M
# [11/03 21:46:37 d2.utils.events]:  eta: 1 day, 13:39:58  iter: 100059  total_loss: 0.4045  loss_cls: 0.04234  loss_box_reg: 0.07111  loss_mask: 0.1466  loss_rpn_cls: 0.0118  loss_rpn_loc: 0.06164  time: 0.3410  data_time: 0.0033  lr: 3e-05  max_mem: 3325M
# [11/03 21:46:44 d2.utils.events]:  eta: 1 day, 13:24:30  iter: 100079  total_loss: 0.301  loss_cls: 0.04575  loss_box_reg: 0.06587  loss_mask: 0.1252  loss_rpn_cls: 0.0154  loss_rpn_loc: 0.0469  time: 0.3397  data_time: 0.0033  lr: 3e-05  max_mem: 3352M
# [11/03 21:46:50 d2.utils.events]:  eta: 1 day, 12:48:55  iter: 100099  total_loss: 0.3068  loss_cls: 0.03685  loss_box_reg: 0.04773  loss_mask: 0.141  loss_rpn_cls: 0.01564  loss_rpn_loc: 0.02395  time: 0.3364  data_time: 0.0036  lr: 3e-05  max_mem: 3352M
# [11/03 21:46:57 d2.utils.events]:  eta: 1 day, 12:41:33  iter: 100119  total_loss: 0.4127  loss_cls: 0.0425  loss_box_reg: 0.07242  loss_mask: 0.1726  loss_rpn_cls: 0.01694  loss_rpn_loc: 0.06512  time: 0.3356  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:04 d2.utils.events]:  eta: 1 day, 12:53:30  iter: 100139  total_loss: 0.5643  loss_cls: 0.06678  loss_box_reg: 0.1167  loss_mask: 0.2107  loss_rpn_cls: 0.01495  loss_rpn_loc: 0.1264  time: 0.3352  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:10 d2.utils.events]:  eta: 1 day, 13:05:59  iter: 100159  total_loss: 0.3542  loss_cls: 0.05885  loss_box_reg: 0.07136  loss_mask: 0.1536  loss_rpn_cls: 0.01347  loss_rpn_loc: 0.03062  time: 0.3353  data_time: 0.0035  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:17 d2.utils.events]:  eta: 1 day, 13:08:17  iter: 100179  total_loss: 0.4955  loss_cls: 0.05778  loss_box_reg: 0.1047  loss_mask: 0.204  loss_rpn_cls: 0.02103  loss_rpn_loc: 0.08829  time: 0.3347  data_time: 0.0033  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:23 d2.utils.events]:  eta: 1 day, 13:08:10  iter: 100199  total_loss: 0.3884  loss_cls: 0.05962  loss_box_reg: 0.08153  loss_mask: 0.1418  loss_rpn_cls: 0.01835  loss_rpn_loc: 0.07422  time: 0.3341  data_time: 0.0035  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:30 d2.utils.events]:  eta: 1 day, 13:13:01  iter: 100219  total_loss: 0.4171  loss_cls: 0.05788  loss_box_reg: 0.09804  loss_mask: 0.1753  loss_rpn_cls: 0.01056  loss_rpn_loc: 0.04534  time: 0.3344  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:37 d2.utils.events]:  eta: 1 day, 13:15:35  iter: 100239  total_loss: 0.397  loss_cls: 0.05289  loss_box_reg: 0.08754  loss_mask: 0.192  loss_rpn_cls: 0.01761  loss_rpn_loc: 0.04296  time: 0.3340  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:44 d2.utils.events]:  eta: 1 day, 13:11:24  iter: 100259  total_loss: 0.5552  loss_cls: 0.06512  loss_box_reg: 0.1112  loss_mask: 0.177  loss_rpn_cls: 0.02027  loss_rpn_loc: 0.1248  time: 0.3340  data_time: 0.0033  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:50 d2.utils.events]:  eta: 1 day, 13:15:21  iter: 100279  total_loss: 0.4557  loss_cls: 0.05444  loss_box_reg: 0.0938  loss_mask: 0.1658  loss_rpn_cls: 0.02053  loss_rpn_loc: 0.06613  time: 0.3340  data_time: 0.0036  lr: 3e-05  max_mem: 3352M
# [11/03 21:47:57 d2.utils.events]:  eta: 1 day, 13:15:43  iter: 100299  total_loss: 0.5292  loss_cls: 0.04967  loss_box_reg: 0.08462  loss_mask: 0.1799  loss_rpn_cls: 0.02068  loss_rpn_loc: 0.1234  time: 0.3341  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:04 d2.utils.events]:  eta: 1 day, 13:15:37  iter: 100319  total_loss: 0.4382  loss_cls: 0.06092  loss_box_reg: 0.08175  loss_mask: 0.1737  loss_rpn_cls: 0.02233  loss_rpn_loc: 0.0585  time: 0.3341  data_time: 0.0033  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:10 d2.utils.events]:  eta: 1 day, 13:12:21  iter: 100339  total_loss: 0.4086  loss_cls: 0.06269  loss_box_reg: 0.0933  loss_mask: 0.1572  loss_rpn_cls: 0.0178  loss_rpn_loc: 0.06618  time: 0.3338  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:17 d2.utils.events]:  eta: 1 day, 13:10:50  iter: 100359  total_loss: 0.5058  loss_cls: 0.04549  loss_box_reg: 0.07641  loss_mask: 0.1757  loss_rpn_cls: 0.01287  loss_rpn_loc: 0.1169  time: 0.3338  data_time: 0.0032  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:24 d2.utils.events]:  eta: 1 day, 13:14:47  iter: 100379  total_loss: 0.3139  loss_cls: 0.05254  loss_box_reg: 0.07969  loss_mask: 0.1398  loss_rpn_cls: 0.01502  loss_rpn_loc: 0.03228  time: 0.3340  data_time: 0.0035  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:30 d2.utils.events]:  eta: 1 day, 13:12:01  iter: 100399  total_loss: 0.4145  loss_cls: 0.06046  loss_box_reg: 0.0803  loss_mask: 0.1646  loss_rpn_cls: 0.02021  loss_rpn_loc: 0.06119  time: 0.3342  data_time: 0.0035  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:37 d2.utils.events]:  eta: 1 day, 13:11:54  iter: 100419  total_loss: 0.4729  loss_cls: 0.06499  loss_box_reg: 0.08641  loss_mask: 0.1777  loss_rpn_cls: 0.02063  loss_rpn_loc: 0.1046  time: 0.3347  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:44 d2.utils.events]:  eta: 1 day, 13:16:45  iter: 100439  total_loss: 0.4043  loss_cls: 0.05331  loss_box_reg: 0.1023  loss_mask: 0.1674  loss_rpn_cls: 0.01706  loss_rpn_loc: 0.06936  time: 0.3349  data_time: 0.0037  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:51 d2.utils.events]:  eta: 1 day, 13:17:10  iter: 100459  total_loss: 0.4617  loss_cls: 0.06952  loss_box_reg: 0.1154  loss_mask: 0.1932  loss_rpn_cls: 0.01327  loss_rpn_loc: 0.08593  time: 0.3348  data_time: 0.0034  lr: 3e-05  max_mem: 3352M
# [11/03 21:48:58 d2.utils.events]:  eta: 1 day, 13:19:55  iter: 100479  total_loss: 0.5414  loss_cls: 0.05839  loss_box_reg: 0.08137  loss_mask: 0.1699  loss_rpn_cls: 0.009566  loss_rpn_loc: 0.1156  time: 0.3351  data_time: 0.0036  lr: 3e-05  max_mem: 3455M
# [11/03 21:49:04 d2.utils.events]:  eta: 1 day, 13:20:34  iter: 100499  total_loss: 0.5563  loss_cls: 0.0614  loss_box_reg: 0.08025  loss_mask: 0.1642  loss_rpn_cls: 0.02258  loss_rpn_loc: 0.1161  time: 0.3353  data_time: 0.0036  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:11 d2.utils.events]:  eta: 1 day, 13:19:28  iter: 100519  total_loss: 0.3539  loss_cls: 0.03799  loss_box_reg: 0.06835  loss_mask: 0.1775  loss_rpn_cls: 0.01303  loss_rpn_loc: 0.03956  time: 0.3354  data_time: 0.0034  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:18 d2.utils.events]:  eta: 1 day, 13:21:55  iter: 100539  total_loss: 0.5142  loss_cls: 0.0691  loss_box_reg: 0.1119  loss_mask: 0.1856  loss_rpn_cls: 0.01583  loss_rpn_loc: 0.077  time: 0.3362  data_time: 0.0035  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:25 d2.utils.events]:  eta: 1 day, 13:22:11  iter: 100559  total_loss: 0.482  loss_cls: 0.05763  loss_box_reg: 0.07382  loss_mask: 0.1696  loss_rpn_cls: 0.01885  loss_rpn_loc: 0.1119  time: 0.3363  data_time: 0.0035  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:32 d2.utils.events]:  eta: 1 day, 13:21:42  iter: 100579  total_loss: 0.4158  loss_cls: 0.04291  loss_box_reg: 0.07182  loss_mask: 0.1591  loss_rpn_cls: 0.01521  loss_rpn_loc: 0.05725  time: 0.3361  data_time: 0.0032  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:39 d2.utils.events]:  eta: 1 day, 13:22:18  iter: 100599  total_loss: 0.4434  loss_cls: 0.05719  loss_box_reg: 0.07773  loss_mask: 0.1642  loss_rpn_cls: 0.02182  loss_rpn_loc: 0.07405  time: 0.3363  data_time: 0.0033  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:45 d2.utils.events]:  eta: 1 day, 13:22:12  iter: 100619  total_loss: 0.4637  loss_cls: 0.06119  loss_box_reg: 0.07733  loss_mask: 0.174  loss_rpn_cls: 0.01778  loss_rpn_loc: 0.07869  time: 0.3363  data_time: 0.0033  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:52 d2.utils.events]:  eta: 1 day, 13:22:05  iter: 100639  total_loss: 0.4466  loss_cls: 0.05491  loss_box_reg: 0.08729  loss_mask: 0.1621  loss_rpn_cls: 0.02236  loss_rpn_loc: 0.08763  time: 0.3363  data_time: 0.0034  lr: 3e-05  max_mem: 3518M
# [11/03 21:49:59 d2.utils.events]:  eta: 1 day, 13:23:53  iter: 100659  total_loss: 0.4428  loss_cls: 0.04798  loss_box_reg: 0.09019  loss_mask: 0.1658  loss_rpn_cls: 0.01679  loss_rpn_loc: 0.05903  time: 0.3365  data_time: 0.0034  lr: 3e-05  max_mem: 3518M
# [11/03 21:50:06 d2.utils.events]:  eta: 1 day, 13:26:35  iter: 100679  total_loss: 0.4376  loss_cls: 0.06025  loss_box_reg: 0.09384  loss_mask: 0.1604  loss_rpn_cls: 0.01622  loss_rpn_loc: 0.08235  time: 0.3374  data_time: 0.0039  lr: 3e-05  max_mem: 3518M
# [11/03 21:50:14 d2.utils.events]:  eta: 1 day, 13:28:27  iter: 100699  total_loss: 0.4077  loss_cls: 0.06031  loss_box_reg: 0.08343  loss_mask: 0.1891  loss_rpn_cls: 0.01201  loss_rpn_loc: 0.04391  time: 0.3381  data_time: 0.0034  lr: 3e-05  max_mem: 3518M
# [11/03 21:50:21 d2.utils.events]:  eta: 1 day, 13:35:13  iter: 100719  total_loss: 0.4148  loss_cls: 0.0773  loss_box_reg: 0.1009  loss_mask: 0.1624  loss_rpn_cls: 0.01642  loss_rpn_loc: 0.05723  time: 0.3385  data_time: 0.0036  lr: 3e-05  max_mem: 3518M
# [11/03 21:50:28 d2.utils.events]:  eta: 1 day, 13:36:45  iter: 100739  total_loss: 0.5688  loss_cls: 0.0661  loss_box_reg: 0.1135  loss_mask: 0.2053  loss_rpn_cls: 0.01896  loss_rpn_loc: 0.09278  time: 0.3388  data_time: 0.0039  lr: 3e-05  max_mem: 3518M
# [11/03 21:50:35 d2.utils.events]:  eta: 1 day, 13:38:57  iter: 100759  total_loss: 0.5082  loss_cls: 0.05846  loss_box_reg: 0.1044  loss_mask: 0.2063  loss_rpn_cls: 0.02046  loss_rpn_loc: 0.07354  time: 0.3396  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:50:42 d2.utils.events]:  eta: 1 day, 13:39:52  iter: 100779  total_loss: 0.3456  loss_cls: 0.04068  loss_box_reg: 0.0714  loss_mask: 0.1471  loss_rpn_cls: 0.01058  loss_rpn_loc: 0.0427  time: 0.3399  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:50:49 d2.utils.events]:  eta: 1 day, 13:41:17  iter: 100799  total_loss: 0.3582  loss_cls: 0.04277  loss_box_reg: 0.0695  loss_mask: 0.1279  loss_rpn_cls: 0.01016  loss_rpn_loc: 0.05385  time: 0.3402  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:50:56 d2.utils.events]:  eta: 1 day, 13:40:47  iter: 100819  total_loss: 0.5911  loss_cls: 0.07181  loss_box_reg: 0.106  loss_mask: 0.1957  loss_rpn_cls: 0.01974  loss_rpn_loc: 0.09666  time: 0.3402  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:03 d2.utils.events]:  eta: 1 day, 13:41:45  iter: 100839  total_loss: 0.4  loss_cls: 0.05343  loss_box_reg: 0.08463  loss_mask: 0.1522  loss_rpn_cls: 0.0139  loss_rpn_loc: 0.07487  time: 0.3404  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:10 d2.utils.events]:  eta: 1 day, 13:41:48  iter: 100859  total_loss: 0.4975  loss_cls: 0.05966  loss_box_reg: 0.07158  loss_mask: 0.1424  loss_rpn_cls: 0.02013  loss_rpn_loc: 0.1371  time: 0.3404  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:17 d2.utils.events]:  eta: 1 day, 13:42:38  iter: 100879  total_loss: 0.3441  loss_cls: 0.04522  loss_box_reg: 0.09231  loss_mask: 0.1779  loss_rpn_cls: 0.01645  loss_rpn_loc: 0.04108  time: 0.3408  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:24 d2.utils.events]:  eta: 1 day, 13:42:13  iter: 100899  total_loss: 0.3642  loss_cls: 0.05184  loss_box_reg: 0.05808  loss_mask: 0.1698  loss_rpn_cls: 0.01411  loss_rpn_loc: 0.04386  time: 0.3408  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:31 d2.utils.events]:  eta: 1 day, 13:41:28  iter: 100919  total_loss: 0.2575  loss_cls: 0.03471  loss_box_reg: 0.05537  loss_mask: 0.1214  loss_rpn_cls: 0.012  loss_rpn_loc: 0.03435  time: 0.3407  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:38 d2.utils.events]:  eta: 1 day, 13:43:47  iter: 100939  total_loss: 0.3802  loss_cls: 0.05442  loss_box_reg: 0.09519  loss_mask: 0.1813  loss_rpn_cls: 0.01574  loss_rpn_loc: 0.02958  time: 0.3411  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:45 d2.utils.events]:  eta: 1 day, 13:46:37  iter: 100959  total_loss: 0.4657  loss_cls: 0.05228  loss_box_reg: 0.08953  loss_mask: 0.1824  loss_rpn_cls: 0.0218  loss_rpn_loc: 0.08055  time: 0.3417  data_time: 0.0041  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:52 d2.utils.events]:  eta: 1 day, 13:45:07  iter: 100979  total_loss: 0.4376  loss_cls: 0.05393  loss_box_reg: 0.06869  loss_mask: 0.1788  loss_rpn_cls: 0.01452  loss_rpn_loc: 0.1366  time: 0.3417  data_time: 0.0039  lr: 3e-05  max_mem: 3569M
# [11/03 21:51:59 d2.utils.events]:  eta: 1 day, 13:46:24  iter: 100999  total_loss: 0.4973  loss_cls: 0.07832  loss_box_reg: 0.1118  loss_mask: 0.1775  loss_rpn_cls: 0.01863  loss_rpn_loc: 0.1059  time: 0.3420  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:06 d2.utils.events]:  eta: 1 day, 13:44:18  iter: 101019  total_loss: 0.3955  loss_cls: 0.05233  loss_box_reg: 0.07947  loss_mask: 0.1712  loss_rpn_cls: 0.01979  loss_rpn_loc: 0.06069  time: 0.3420  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:13 d2.utils.events]:  eta: 1 day, 13:46:10  iter: 101039  total_loss: 0.3437  loss_cls: 0.04337  loss_box_reg: 0.08005  loss_mask: 0.1646  loss_rpn_cls: 0.02004  loss_rpn_loc: 0.04404  time: 0.3420  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:20 d2.utils.events]:  eta: 1 day, 13:50:44  iter: 101059  total_loss: 0.4183  loss_cls: 0.05086  loss_box_reg: 0.08742  loss_mask: 0.1796  loss_rpn_cls: 0.01492  loss_rpn_loc: 0.06949  time: 0.3420  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:27 d2.utils.events]:  eta: 1 day, 13:51:02  iter: 101079  total_loss: 0.336  loss_cls: 0.05271  loss_box_reg: 0.07289  loss_mask: 0.1539  loss_rpn_cls: 0.01833  loss_rpn_loc: 0.03107  time: 0.3420  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:34 d2.utils.events]:  eta: 1 day, 13:57:44  iter: 101099  total_loss: 0.3494  loss_cls: 0.0436  loss_box_reg: 0.08339  loss_mask: 0.1581  loss_rpn_cls: 0.01333  loss_rpn_loc: 0.04565  time: 0.3422  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:41 d2.utils.events]:  eta: 1 day, 14:03:40  iter: 101119  total_loss: 0.5691  loss_cls: 0.06108  loss_box_reg: 0.08346  loss_mask: 0.2003  loss_rpn_cls: 0.01739  loss_rpn_loc: 0.1317  time: 0.3426  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:48 d2.utils.events]:  eta: 1 day, 14:06:32  iter: 101139  total_loss: 0.4249  loss_cls: 0.06852  loss_box_reg: 0.1034  loss_mask: 0.1663  loss_rpn_cls: 0.01752  loss_rpn_loc: 0.08569  time: 0.3429  data_time: 0.0040  lr: 3e-05  max_mem: 3569M
# [11/03 21:52:56 d2.utils.events]:  eta: 1 day, 14:09:32  iter: 101159  total_loss: 0.5371  loss_cls: 0.06956  loss_box_reg: 0.1085  loss_mask: 0.1687  loss_rpn_cls: 0.01872  loss_rpn_loc: 0.0854  time: 0.3433  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:03 d2.utils.events]:  eta: 1 day, 14:09:33  iter: 101179  total_loss: 0.4495  loss_cls: 0.0521  loss_box_reg: 0.08257  loss_mask: 0.1535  loss_rpn_cls: 0.01801  loss_rpn_loc: 0.1026  time: 0.3435  data_time: 0.0056  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:10 d2.utils.events]:  eta: 1 day, 14:14:12  iter: 101199  total_loss: 0.5274  loss_cls: 0.05889  loss_box_reg: 0.1082  loss_mask: 0.196  loss_rpn_cls: 0.02654  loss_rpn_loc: 0.08913  time: 0.3438  data_time: 0.0039  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:17 d2.utils.events]:  eta: 1 day, 14:15:55  iter: 101219  total_loss: 0.3956  loss_cls: 0.05578  loss_box_reg: 0.07441  loss_mask: 0.1531  loss_rpn_cls: 0.01794  loss_rpn_loc: 0.04198  time: 0.3440  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:24 d2.utils.events]:  eta: 1 day, 14:17:54  iter: 101239  total_loss: 0.5062  loss_cls: 0.06763  loss_box_reg: 0.09823  loss_mask: 0.187  loss_rpn_cls: 0.03128  loss_rpn_loc: 0.09929  time: 0.3442  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:31 d2.utils.events]:  eta: 1 day, 14:21:20  iter: 101259  total_loss: 0.4429  loss_cls: 0.04731  loss_box_reg: 0.07405  loss_mask: 0.1803  loss_rpn_cls: 0.01878  loss_rpn_loc: 0.05314  time: 0.3445  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:38 d2.utils.events]:  eta: 1 day, 14:22:45  iter: 101279  total_loss: 0.4509  loss_cls: 0.06364  loss_box_reg: 0.08571  loss_mask: 0.1691  loss_rpn_cls: 0.01707  loss_rpn_loc: 0.07653  time: 0.3444  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:45 d2.utils.events]:  eta: 1 day, 14:23:10  iter: 101299  total_loss: 0.3884  loss_cls: 0.056  loss_box_reg: 0.0804  loss_mask: 0.1467  loss_rpn_cls: 0.01857  loss_rpn_loc: 0.04768  time: 0.3444  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:52 d2.utils.events]:  eta: 1 day, 14:27:37  iter: 101319  total_loss: 0.3268  loss_cls: 0.04116  loss_box_reg: 0.05675  loss_mask: 0.1601  loss_rpn_cls: 0.01696  loss_rpn_loc: 0.02878  time: 0.3445  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:53:59 d2.utils.events]:  eta: 1 day, 14:30:34  iter: 101339  total_loss: 0.4056  loss_cls: 0.05635  loss_box_reg: 0.08577  loss_mask: 0.1781  loss_rpn_cls: 0.0125  loss_rpn_loc: 0.04954  time: 0.3445  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:06 d2.utils.events]:  eta: 1 day, 14:31:52  iter: 101359  total_loss: 0.3912  loss_cls: 0.05465  loss_box_reg: 0.08052  loss_mask: 0.1594  loss_rpn_cls: 0.01392  loss_rpn_loc: 0.06039  time: 0.3445  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:13 d2.utils.events]:  eta: 1 day, 14:34:34  iter: 101379  total_loss: 0.4839  loss_cls: 0.07055  loss_box_reg: 0.0898  loss_mask: 0.175  loss_rpn_cls: 0.01535  loss_rpn_loc: 0.09131  time: 0.3445  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:20 d2.utils.events]:  eta: 1 day, 14:35:44  iter: 101399  total_loss: 0.3658  loss_cls: 0.05046  loss_box_reg: 0.07635  loss_mask: 0.1778  loss_rpn_cls: 0.01463  loss_rpn_loc: 0.05183  time: 0.3447  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:27 d2.utils.events]:  eta: 1 day, 14:37:45  iter: 101419  total_loss: 0.3313  loss_cls: 0.04924  loss_box_reg: 0.07528  loss_mask: 0.1495  loss_rpn_cls: 0.01154  loss_rpn_loc: 0.0303  time: 0.3447  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:34 d2.utils.events]:  eta: 1 day, 14:38:07  iter: 101439  total_loss: 0.458  loss_cls: 0.06153  loss_box_reg: 0.09346  loss_mask: 0.208  loss_rpn_cls: 0.01555  loss_rpn_loc: 0.08792  time: 0.3449  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:41 d2.utils.events]:  eta: 1 day, 14:38:38  iter: 101459  total_loss: 0.5162  loss_cls: 0.06196  loss_box_reg: 0.09304  loss_mask: 0.1723  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.06739  time: 0.3450  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:48 d2.utils.events]:  eta: 1 day, 14:40:38  iter: 101479  total_loss: 0.4463  loss_cls: 0.0395  loss_box_reg: 0.08383  loss_mask: 0.1787  loss_rpn_cls: 0.01505  loss_rpn_loc: 0.06146  time: 0.3451  data_time: 0.0039  lr: 3e-05  max_mem: 3569M
# [11/03 21:54:55 d2.utils.events]:  eta: 1 day, 14:41:06  iter: 101499  total_loss: 0.4358  loss_cls: 0.04794  loss_box_reg: 0.07537  loss_mask: 0.1426  loss_rpn_cls: 0.01705  loss_rpn_loc: 0.06902  time: 0.3450  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:02 d2.utils.events]:  eta: 1 day, 14:39:39  iter: 101519  total_loss: 0.3997  loss_cls: 0.04533  loss_box_reg: 0.07015  loss_mask: 0.1736  loss_rpn_cls: 0.01303  loss_rpn_loc: 0.04127  time: 0.3448  data_time: 0.0032  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:09 d2.utils.events]:  eta: 1 day, 14:40:52  iter: 101539  total_loss: 0.5818  loss_cls: 0.05353  loss_box_reg: 0.09865  loss_mask: 0.2159  loss_rpn_cls: 0.02079  loss_rpn_loc: 0.1772  time: 0.3450  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:16 d2.utils.events]:  eta: 1 day, 14:43:09  iter: 101559  total_loss: 0.4336  loss_cls: 0.05065  loss_box_reg: 0.08368  loss_mask: 0.1663  loss_rpn_cls: 0.01734  loss_rpn_loc: 0.07948  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:23 d2.utils.events]:  eta: 1 day, 14:44:44  iter: 101579  total_loss: 0.5133  loss_cls: 0.055  loss_box_reg: 0.09408  loss_mask: 0.1862  loss_rpn_cls: 0.01703  loss_rpn_loc: 0.09597  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:30 d2.utils.events]:  eta: 1 day, 14:47:35  iter: 101599  total_loss: 0.487  loss_cls: 0.05964  loss_box_reg: 0.1026  loss_mask: 0.2008  loss_rpn_cls: 0.02017  loss_rpn_loc: 0.1415  time: 0.3450  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:37 d2.utils.events]:  eta: 1 day, 14:47:01  iter: 101619  total_loss: 0.6003  loss_cls: 0.07624  loss_box_reg: 0.1181  loss_mask: 0.1972  loss_rpn_cls: 0.02214  loss_rpn_loc: 0.1172  time: 0.3450  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:43 d2.utils.events]:  eta: 1 day, 14:49:21  iter: 101639  total_loss: 0.4714  loss_cls: 0.06084  loss_box_reg: 0.09211  loss_mask: 0.1699  loss_rpn_cls: 0.017  loss_rpn_loc: 0.03988  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:50 d2.utils.events]:  eta: 1 day, 14:46:43  iter: 101659  total_loss: 0.4916  loss_cls: 0.0553  loss_box_reg: 0.08017  loss_mask: 0.1753  loss_rpn_cls: 0.02567  loss_rpn_loc: 0.08215  time: 0.3448  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:55:57 d2.utils.events]:  eta: 1 day, 14:44:55  iter: 101679  total_loss: 0.4713  loss_cls: 0.04517  loss_box_reg: 0.07703  loss_mask: 0.1786  loss_rpn_cls: 0.01446  loss_rpn_loc: 0.08644  time: 0.3449  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:04 d2.utils.events]:  eta: 1 day, 14:42:50  iter: 101699  total_loss: 0.4105  loss_cls: 0.05152  loss_box_reg: 0.09388  loss_mask: 0.1857  loss_rpn_cls: 0.01758  loss_rpn_loc: 0.08458  time: 0.3449  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:11 d2.utils.events]:  eta: 1 day, 14:42:43  iter: 101719  total_loss: 0.4041  loss_cls: 0.05023  loss_box_reg: 0.08422  loss_mask: 0.1555  loss_rpn_cls: 0.01865  loss_rpn_loc: 0.06507  time: 0.3450  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:18 d2.utils.events]:  eta: 1 day, 14:39:15  iter: 101739  total_loss: 0.4703  loss_cls: 0.06142  loss_box_reg: 0.09921  loss_mask: 0.1745  loss_rpn_cls: 0.01676  loss_rpn_loc: 0.06314  time: 0.3449  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:25 d2.utils.events]:  eta: 1 day, 14:36:24  iter: 101759  total_loss: 0.548  loss_cls: 0.07848  loss_box_reg: 0.1084  loss_mask: 0.1912  loss_rpn_cls: 0.01534  loss_rpn_loc: 0.06438  time: 0.3449  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:32 d2.utils.events]:  eta: 1 day, 14:36:17  iter: 101779  total_loss: 0.4897  loss_cls: 0.04731  loss_box_reg: 0.08413  loss_mask: 0.1824  loss_rpn_cls: 0.02395  loss_rpn_loc: 0.08621  time: 0.3449  data_time: 0.0033  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:39 d2.utils.events]:  eta: 1 day, 14:34:02  iter: 101799  total_loss: 0.4868  loss_cls: 0.04947  loss_box_reg: 0.07039  loss_mask: 0.1884  loss_rpn_cls: 0.01763  loss_rpn_loc: 0.1386  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:46 d2.utils.events]:  eta: 1 day, 14:35:51  iter: 101819  total_loss: 0.3729  loss_cls: 0.03508  loss_box_reg: 0.09464  loss_mask: 0.1717  loss_rpn_cls: 0.01572  loss_rpn_loc: 0.04512  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:52 d2.utils.events]:  eta: 1 day, 14:35:30  iter: 101839  total_loss: 0.4874  loss_cls: 0.07689  loss_box_reg: 0.1004  loss_mask: 0.1838  loss_rpn_cls: 0.02579  loss_rpn_loc: 0.08264  time: 0.3449  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:56:59 d2.utils.events]:  eta: 1 day, 14:35:06  iter: 101859  total_loss: 0.498  loss_cls: 0.04721  loss_box_reg: 0.06599  loss_mask: 0.1815  loss_rpn_cls: 0.01883  loss_rpn_loc: 0.1477  time: 0.3448  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:06 d2.utils.events]:  eta: 1 day, 14:33:34  iter: 101879  total_loss: 0.4296  loss_cls: 0.05708  loss_box_reg: 0.0972  loss_mask: 0.1745  loss_rpn_cls: 0.01841  loss_rpn_loc: 0.07303  time: 0.3448  data_time: 0.0033  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:13 d2.utils.events]:  eta: 1 day, 14:35:23  iter: 101899  total_loss: 0.4435  loss_cls: 0.04481  loss_box_reg: 0.08212  loss_mask: 0.1772  loss_rpn_cls: 0.01792  loss_rpn_loc: 0.0547  time: 0.3448  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:20 d2.utils.events]:  eta: 1 day, 14:35:16  iter: 101919  total_loss: 0.395  loss_cls: 0.03961  loss_box_reg: 0.05994  loss_mask: 0.1575  loss_rpn_cls: 0.0155  loss_rpn_loc: 0.05837  time: 0.3448  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:27 d2.utils.events]:  eta: 1 day, 14:33:13  iter: 101939  total_loss: 0.4897  loss_cls: 0.04955  loss_box_reg: 0.0727  loss_mask: 0.2058  loss_rpn_cls: 0.0231  loss_rpn_loc: 0.1117  time: 0.3448  data_time: 0.0031  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:34 d2.utils.events]:  eta: 1 day, 14:30:47  iter: 101959  total_loss: 0.3914  loss_cls: 0.04486  loss_box_reg: 0.08829  loss_mask: 0.1807  loss_rpn_cls: 0.0142  loss_rpn_loc: 0.04763  time: 0.3448  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:41 d2.utils.events]:  eta: 1 day, 14:33:46  iter: 101979  total_loss: 0.5234  loss_cls: 0.04707  loss_box_reg: 0.08581  loss_mask: 0.1754  loss_rpn_cls: 0.01357  loss_rpn_loc: 0.09972  time: 0.3448  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:48 d2.utils.events]:  eta: 1 day, 14:33:39  iter: 101999  total_loss: 0.409  loss_cls: 0.06153  loss_box_reg: 0.09056  loss_mask: 0.1877  loss_rpn_cls: 0.01928  loss_rpn_loc: 0.05527  time: 0.3449  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:57:55 d2.utils.events]:  eta: 1 day, 14:33:32  iter: 102019  total_loss: 0.3607  loss_cls: 0.04307  loss_box_reg: 0.06986  loss_mask: 0.1413  loss_rpn_cls: 0.01638  loss_rpn_loc: 0.03983  time: 0.3449  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:02 d2.utils.events]:  eta: 1 day, 14:36:45  iter: 102039  total_loss: 0.3164  loss_cls: 0.03496  loss_box_reg: 0.07048  loss_mask: 0.1446  loss_rpn_cls: 0.01982  loss_rpn_loc: 0.03973  time: 0.3452  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:09 d2.utils.events]:  eta: 1 day, 14:36:16  iter: 102059  total_loss: 0.4748  loss_cls: 0.05499  loss_box_reg: 0.07872  loss_mask: 0.1725  loss_rpn_cls: 0.02381  loss_rpn_loc: 0.05203  time: 0.3450  data_time: 0.0033  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:16 d2.utils.events]:  eta: 1 day, 14:36:09  iter: 102079  total_loss: 0.3707  loss_cls: 0.04385  loss_box_reg: 0.06895  loss_mask: 0.142  loss_rpn_cls: 0.01189  loss_rpn_loc: 0.04952  time: 0.3450  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:23 d2.utils.events]:  eta: 1 day, 14:34:09  iter: 102099  total_loss: 0.3515  loss_cls: 0.047  loss_box_reg: 0.06719  loss_mask: 0.1562  loss_rpn_cls: 0.01637  loss_rpn_loc: 0.03607  time: 0.3451  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:30 d2.utils.events]:  eta: 1 day, 14:30:36  iter: 102119  total_loss: 0.485  loss_cls: 0.06363  loss_box_reg: 0.1053  loss_mask: 0.2301  loss_rpn_cls: 0.02009  loss_rpn_loc: 0.1123  time: 0.3451  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:37 d2.utils.events]:  eta: 1 day, 14:29:11  iter: 102139  total_loss: 0.3493  loss_cls: 0.04382  loss_box_reg: 0.0643  loss_mask: 0.1603  loss_rpn_cls: 0.01853  loss_rpn_loc: 0.04479  time: 0.3452  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:44 d2.utils.events]:  eta: 1 day, 14:25:45  iter: 102159  total_loss: 0.5634  loss_cls: 0.06636  loss_box_reg: 0.1199  loss_mask: 0.1912  loss_rpn_cls: 0.01635  loss_rpn_loc: 0.1023  time: 0.3452  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:51 d2.utils.events]:  eta: 1 day, 14:26:41  iter: 102179  total_loss: 0.4781  loss_cls: 0.06601  loss_box_reg: 0.1148  loss_mask: 0.2002  loss_rpn_cls: 0.01743  loss_rpn_loc: 0.0585  time: 0.3452  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:58:57 d2.utils.events]:  eta: 1 day, 14:25:48  iter: 102199  total_loss: 0.3877  loss_cls: 0.05259  loss_box_reg: 0.089  loss_mask: 0.1566  loss_rpn_cls: 0.0139  loss_rpn_loc: 0.05799  time: 0.3451  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:04 d2.utils.events]:  eta: 1 day, 14:25:42  iter: 102219  total_loss: 0.618  loss_cls: 0.074  loss_box_reg: 0.1136  loss_mask: 0.214  loss_rpn_cls: 0.02025  loss_rpn_loc: 0.1175  time: 0.3452  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:11 d2.utils.events]:  eta: 1 day, 14:19:20  iter: 102239  total_loss: 0.5001  loss_cls: 0.05448  loss_box_reg: 0.0738  loss_mask: 0.194  loss_rpn_cls: 0.01476  loss_rpn_loc: 0.07963  time: 0.3452  data_time: 0.0037  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:18 d2.utils.events]:  eta: 1 day, 14:18:49  iter: 102259  total_loss: 0.5027  loss_cls: 0.0716  loss_box_reg: 0.09731  loss_mask: 0.1893  loss_rpn_cls: 0.01899  loss_rpn_loc: 0.08991  time: 0.3452  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:25 d2.utils.events]:  eta: 1 day, 14:19:04  iter: 102279  total_loss: 0.519  loss_cls: 0.06188  loss_box_reg: 0.1109  loss_mask: 0.2043  loss_rpn_cls: 0.02167  loss_rpn_loc: 0.06887  time: 0.3451  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:32 d2.utils.events]:  eta: 1 day, 14:20:59  iter: 102299  total_loss: 0.3831  loss_cls: 0.05007  loss_box_reg: 0.09395  loss_mask: 0.1569  loss_rpn_cls: 0.01389  loss_rpn_loc: 0.0665  time: 0.3452  data_time: 0.0038  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:39 d2.utils.events]:  eta: 1 day, 14:20:52  iter: 102319  total_loss: 0.5024  loss_cls: 0.06769  loss_box_reg: 0.1143  loss_mask: 0.2413  loss_rpn_cls: 0.02555  loss_rpn_loc: 0.06317  time: 0.3452  data_time: 0.0033  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:46 d2.utils.events]:  eta: 1 day, 14:22:32  iter: 102339  total_loss: 0.4614  loss_cls: 0.05792  loss_box_reg: 0.1007  loss_mask: 0.1632  loss_rpn_cls: 0.01507  loss_rpn_loc: 0.05411  time: 0.3453  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 21:59:53 d2.utils.events]:  eta: 1 day, 14:23:11  iter: 102359  total_loss: 0.4683  loss_cls: 0.05267  loss_box_reg: 0.086  loss_mask: 0.1893  loss_rpn_cls: 0.02096  loss_rpn_loc: 0.05873  time: 0.3453  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:00 d2.utils.events]:  eta: 1 day, 14:20:31  iter: 102379  total_loss: 0.4803  loss_cls: 0.06119  loss_box_reg: 0.09851  loss_mask: 0.2003  loss_rpn_cls: 0.01661  loss_rpn_loc: 0.07263  time: 0.3454  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:07 d2.utils.events]:  eta: 1 day, 14:17:14  iter: 102399  total_loss: 0.4275  loss_cls: 0.0379  loss_box_reg: 0.06874  loss_mask: 0.1344  loss_rpn_cls: 0.02118  loss_rpn_loc: 0.0766  time: 0.3454  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:14 d2.utils.events]:  eta: 1 day, 14:16:23  iter: 102419  total_loss: 0.4118  loss_cls: 0.04901  loss_box_reg: 0.0822  loss_mask: 0.1979  loss_rpn_cls: 0.01777  loss_rpn_loc: 0.06975  time: 0.3454  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:21 d2.utils.events]:  eta: 1 day, 14:14:31  iter: 102439  total_loss: 0.4177  loss_cls: 0.06218  loss_box_reg: 0.08826  loss_mask: 0.1836  loss_rpn_cls: 0.01304  loss_rpn_loc: 0.05656  time: 0.3454  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:28 d2.utils.events]:  eta: 1 day, 14:14:24  iter: 102459  total_loss: 0.4632  loss_cls: 0.0598  loss_box_reg: 0.1083  loss_mask: 0.2023  loss_rpn_cls: 0.01641  loss_rpn_loc: 0.0536  time: 0.3453  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:34 d2.utils.events]:  eta: 1 day, 14:11:17  iter: 102479  total_loss: 0.424  loss_cls: 0.04512  loss_box_reg: 0.06535  loss_mask: 0.1853  loss_rpn_cls: 0.01675  loss_rpn_loc: 0.05631  time: 0.3453  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:41 d2.utils.events]:  eta: 1 day, 14:10:17  iter: 102499  total_loss: 0.4847  loss_cls: 0.05552  loss_box_reg: 0.06576  loss_mask: 0.1917  loss_rpn_cls: 0.02168  loss_rpn_loc: 0.1154  time: 0.3451  data_time: 0.0034  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:48 d2.utils.events]:  eta: 1 day, 14:10:36  iter: 102519  total_loss: 0.4271  loss_cls: 0.06494  loss_box_reg: 0.09689  loss_mask: 0.1718  loss_rpn_cls: 0.01316  loss_rpn_loc: 0.05276  time: 0.3452  data_time: 0.0035  lr: 3e-05  max_mem: 3569M
# [11/03 22:00:55 d2.utils.events]:  eta: 1 day, 14:09:36  iter: 102539  total_loss: 0.4876  loss_cls: 0.06168  loss_box_reg: 0.1105  loss_mask: 0.1775  loss_rpn_cls: 0.02324  loss_rpn_loc: 0.06965  time: 0.3452  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 22:01:02 d2.utils.events]:  eta: 1 day, 14:09:30  iter: 102559  total_loss: 0.3852  loss_cls: 0.04959  loss_box_reg: 0.07224  loss_mask: 0.1265  loss_rpn_cls: 0.02166  loss_rpn_loc: 0.1121  time: 0.3453  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# [11/03 22:01:10 d2.utils.events]:  eta: 1 day, 14:10:42  iter: 102579  total_loss: 0.3559  loss_cls: 0.04256  loss_box_reg: 0.07594  loss_mask: 0.1828  loss_rpn_cls: 0.009532  loss_rpn_loc: 0.02175  time: 0.3454  data_time: 0.0040  lr: 3e-05  max_mem: 3569M
# [11/03 22:01:17 d2.utils.events]:  eta: 1 day, 14:09:44  iter: 102599  total_loss: 0.4  loss_cls: 0.05624  loss_box_reg: 0.07452  loss_mask: 0.1781  loss_rpn_cls: 0.01899  loss_rpn_loc: 0.06421  time: 0.3456  data_time: 0.0036  lr: 3e-05  max_mem: 3569M
# ...
# [11/04 11:20:07 d2.utils.events]:  eta: 1 day, 1:03:37  iter: 241659  total_loss: 0.2317  loss_cls: 0.02485  loss_box_reg: 0.05292  loss_mask: 0.1094  loss_rpn_cls: 0.009209  loss_rpn_loc: 0.0122  time: 0.3439  data_time: 0.0034  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:14 d2.utils.events]:  eta: 1 day, 1:06:11  iter: 241679  total_loss: 0.6372  loss_cls: 0.06351  loss_box_reg: 0.1098  loss_mask: 0.2017  loss_rpn_cls: 0.02416  loss_rpn_loc: 0.1648  time: 0.3439  data_time: 0.0034  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:21 d2.utils.events]:  eta: 1 day, 1:06:38  iter: 241699  total_loss: 0.3317  loss_cls: 0.04477  loss_box_reg: 0.07793  loss_mask: 0.1469  loss_rpn_cls: 0.01299  loss_rpn_loc: 0.05324  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:28 d2.utils.events]:  eta: 1 day, 1:06:22  iter: 241719  total_loss: 0.3846  loss_cls: 0.05101  loss_box_reg: 0.07851  loss_mask: 0.1703  loss_rpn_cls: 0.01517  loss_rpn_loc: 0.04236  time: 0.3439  data_time: 0.0033  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:35 d2.utils.events]:  eta: 1 day, 1:06:50  iter: 241739  total_loss: 0.3426  loss_cls: 0.05199  loss_box_reg: 0.0841  loss_mask: 0.125  loss_rpn_cls: 0.01508  loss_rpn_loc: 0.03933  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:41 d2.utils.events]:  eta: 1 day, 1:06:51  iter: 241759  total_loss: 0.4113  loss_cls: 0.06121  loss_box_reg: 0.1083  loss_mask: 0.1733  loss_rpn_cls: 0.01837  loss_rpn_loc: 0.07468  time: 0.3439  data_time: 0.0034  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:48 d2.utils.events]:  eta: 1 day, 1:06:01  iter: 241779  total_loss: 0.3746  loss_cls: 0.04977  loss_box_reg: 0.08798  loss_mask: 0.1508  loss_rpn_cls: 0.01447  loss_rpn_loc: 0.05302  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:20:55 d2.utils.events]:  eta: 1 day, 1:06:08  iter: 241799  total_loss: 0.3604  loss_cls: 0.0444  loss_box_reg: 0.07155  loss_mask: 0.1614  loss_rpn_cls: 0.01516  loss_rpn_loc: 0.07271  time: 0.3439  data_time: 0.0033  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:02 d2.utils.events]:  eta: 1 day, 1:04:52  iter: 241819  total_loss: 0.327  loss_cls: 0.04171  loss_box_reg: 0.07306  loss_mask: 0.1312  loss_rpn_cls: 0.008974  loss_rpn_loc: 0.02822  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:09 d2.utils.events]:  eta: 1 day, 1:04:29  iter: 241839  total_loss: 0.4529  loss_cls: 0.05364  loss_box_reg: 0.08291  loss_mask: 0.1448  loss_rpn_cls: 0.02056  loss_rpn_loc: 0.09358  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:16 d2.utils.events]:  eta: 1 day, 1:00:33  iter: 241859  total_loss: 0.4322  loss_cls: 0.04713  loss_box_reg: 0.07565  loss_mask: 0.1312  loss_rpn_cls: 0.0159  loss_rpn_loc: 0.08128  time: 0.3439  data_time: 0.0034  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:22 d2.utils.events]:  eta: 1 day, 0:59:44  iter: 241879  total_loss: 0.3262  loss_cls: 0.04136  loss_box_reg: 0.05945  loss_mask: 0.1274  loss_rpn_cls: 0.01778  loss_rpn_loc: 0.03027  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:29 d2.utils.events]:  eta: 1 day, 0:59:02  iter: 241899  total_loss: 0.441  loss_cls: 0.05061  loss_box_reg: 0.07727  loss_mask: 0.1722  loss_rpn_cls: 0.02239  loss_rpn_loc: 0.1262  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:36 d2.utils.events]:  eta: 1 day, 0:58:04  iter: 241919  total_loss: 0.3496  loss_cls: 0.0421  loss_box_reg: 0.0843  loss_mask: 0.1532  loss_rpn_cls: 0.01312  loss_rpn_loc: 0.04332  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:43 d2.utils.events]:  eta: 1 day, 0:59:01  iter: 241939  total_loss: 0.4837  loss_cls: 0.06596  loss_box_reg: 0.09566  loss_mask: 0.181  loss_rpn_cls: 0.0213  loss_rpn_loc: 0.09002  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:50 d2.utils.events]:  eta: 1 day, 0:58:18  iter: 241959  total_loss: 0.346  loss_cls: 0.03769  loss_box_reg: 0.06073  loss_mask: 0.1447  loss_rpn_cls: 0.01184  loss_rpn_loc: 0.02883  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:21:56 d2.utils.events]:  eta: 1 day, 0:57:31  iter: 241979  total_loss: 0.4178  loss_cls: 0.06876  loss_box_reg: 0.1035  loss_mask: 0.1766  loss_rpn_cls: 0.01628  loss_rpn_loc: 0.03867  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:03 d2.utils.events]:  eta: 1 day, 0:56:07  iter: 241999  total_loss: 0.4118  loss_cls: 0.04791  loss_box_reg: 0.07966  loss_mask: 0.1733  loss_rpn_cls: 0.01721  loss_rpn_loc: 0.05294  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:10 d2.utils.events]:  eta: 1 day, 0:56:20  iter: 242019  total_loss: 0.4833  loss_cls: 0.07056  loss_box_reg: 0.09557  loss_mask: 0.1871  loss_rpn_cls: 0.01907  loss_rpn_loc: 0.08716  time: 0.3439  data_time: 0.0038  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:18 d2.utils.events]:  eta: 1 day, 0:56:54  iter: 242039  total_loss: 0.4028  loss_cls: 0.05261  loss_box_reg: 0.07065  loss_mask: 0.1672  loss_rpn_cls: 0.01387  loss_rpn_loc: 0.0784  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:25 d2.utils.events]:  eta: 1 day, 0:55:16  iter: 242059  total_loss: 0.4417  loss_cls: 0.04823  loss_box_reg: 0.07311  loss_mask: 0.1474  loss_rpn_cls: 0.01181  loss_rpn_loc: 0.03196  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:32 d2.utils.events]:  eta: 1 day, 0:54:12  iter: 242079  total_loss: 0.5479  loss_cls: 0.05813  loss_box_reg: 0.118  loss_mask: 0.17  loss_rpn_cls: 0.02352  loss_rpn_loc: 0.09026  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:39 d2.utils.events]:  eta: 1 day, 0:50:19  iter: 242099  total_loss: 0.4486  loss_cls: 0.05482  loss_box_reg: 0.08439  loss_mask: 0.1883  loss_rpn_cls: 0.0208  loss_rpn_loc: 0.105  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:46 d2.utils.events]:  eta: 1 day, 0:48:18  iter: 242119  total_loss: 0.3952  loss_cls: 0.05224  loss_box_reg: 0.08543  loss_mask: 0.1574  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.08964  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:53 d2.utils.events]:  eta: 1 day, 0:45:56  iter: 242139  total_loss: 0.4352  loss_cls: 0.06102  loss_box_reg: 0.09249  loss_mask: 0.158  loss_rpn_cls: 0.01583  loss_rpn_loc: 0.05604  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:22:59 d2.utils.events]:  eta: 1 day, 0:45:49  iter: 242159  total_loss: 0.4819  loss_cls: 0.07306  loss_box_reg: 0.129  loss_mask: 0.1872  loss_rpn_cls: 0.01843  loss_rpn_loc: 0.06692  time: 0.3439  data_time: 0.0038  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:06 d2.utils.events]:  eta: 1 day, 0:46:29  iter: 242179  total_loss: 0.3462  loss_cls: 0.04174  loss_box_reg: 0.07646  loss_mask: 0.1613  loss_rpn_cls: 0.0165  loss_rpn_loc: 0.0585  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:13 d2.utils.events]:  eta: 1 day, 0:46:14  iter: 242199  total_loss: 0.3991  loss_cls: 0.04434  loss_box_reg: 0.07724  loss_mask: 0.1801  loss_rpn_cls: 0.0112  loss_rpn_loc: 0.04404  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:21 d2.utils.events]:  eta: 1 day, 0:48:48  iter: 242219  total_loss: 0.4  loss_cls: 0.05115  loss_box_reg: 0.07986  loss_mask: 0.1696  loss_rpn_cls: 0.01382  loss_rpn_loc: 0.1052  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:28 d2.utils.events]:  eta: 1 day, 0:48:23  iter: 242239  total_loss: 0.5549  loss_cls: 0.07459  loss_box_reg: 0.1022  loss_mask: 0.1865  loss_rpn_cls: 0.02082  loss_rpn_loc: 0.08208  time: 0.3439  data_time: 0.0033  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:34 d2.utils.events]:  eta: 1 day, 0:48:16  iter: 242259  total_loss: 0.5123  loss_cls: 0.06803  loss_box_reg: 0.09684  loss_mask: 0.1829  loss_rpn_cls: 0.01573  loss_rpn_loc: 0.07835  time: 0.3439  data_time: 0.0033  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:41 d2.utils.events]:  eta: 1 day, 0:48:09  iter: 242279  total_loss: 0.3365  loss_cls: 0.03963  loss_box_reg: 0.06642  loss_mask: 0.1316  loss_rpn_cls: 0.01113  loss_rpn_loc: 0.05751  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:48 d2.utils.events]:  eta: 1 day, 0:45:39  iter: 242299  total_loss: 0.4825  loss_cls: 0.0584  loss_box_reg: 0.09239  loss_mask: 0.1757  loss_rpn_cls: 0.01423  loss_rpn_loc: 0.1012  time: 0.3439  data_time: 0.0032  lr: 9e-06  max_mem: 3718M
# [11/04 11:23:55 d2.utils.events]:  eta: 1 day, 0:44:53  iter: 242319  total_loss: 0.4442  loss_cls: 0.05978  loss_box_reg: 0.09675  loss_mask: 0.1609  loss_rpn_cls: 0.01651  loss_rpn_loc: 0.06826  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:02 d2.utils.events]:  eta: 1 day, 0:43:41  iter: 242339  total_loss: 0.706  loss_cls: 0.0573  loss_box_reg: 0.1058  loss_mask: 0.1698  loss_rpn_cls: 0.02797  loss_rpn_loc: 0.1421  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:09 d2.utils.events]:  eta: 1 day, 0:44:48  iter: 242359  total_loss: 0.5245  loss_cls: 0.06183  loss_box_reg: 0.0927  loss_mask: 0.1747  loss_rpn_cls: 0.0167  loss_rpn_loc: 0.1004  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:16 d2.utils.events]:  eta: 1 day, 0:42:56  iter: 242379  total_loss: 0.3598  loss_cls: 0.06007  loss_box_reg: 0.07978  loss_mask: 0.1458  loss_rpn_cls: 0.01646  loss_rpn_loc: 0.09946  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:23 d2.utils.events]:  eta: 1 day, 0:44:58  iter: 242399  total_loss: 0.461  loss_cls: 0.0657  loss_box_reg: 0.08702  loss_mask: 0.1722  loss_rpn_cls: 0.01631  loss_rpn_loc: 0.0613  time: 0.3439  data_time: 0.0035  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:30 d2.utils.events]:  eta: 1 day, 0:45:31  iter: 242419  total_loss: 0.487  loss_cls: 0.06371  loss_box_reg: 0.09064  loss_mask: 0.1673  loss_rpn_cls: 0.01358  loss_rpn_loc: 0.07342  time: 0.3439  data_time: 0.0036  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:38 d2.utils.events]:  eta: 1 day, 0:45:05  iter: 242439  total_loss: 0.4311  loss_cls: 0.05024  loss_box_reg: 0.07505  loss_mask: 0.1752  loss_rpn_cls: 0.01896  loss_rpn_loc: 0.06916  time: 0.3439  data_time: 0.0038  lr: 9e-06  max_mem: 3718M
# [11/04 11:24:39 d2.engine.hooks]: Overall training speed: 142442 iterations in 13:36:31 (0.3439 s / it)
# [11/04 11:24:39 d2.engine.hooks]: Total training time: 13:38:22 (0:01:51 on hooks)
# [11/04 11:24:39 d2.utils.events]:  eta: 1 day, 0:44:46  iter: 242444  total_loss: 0.4778  loss_cls: 0.05857  loss_box_reg: 0.09098  loss_mask: 0.1923  loss_rpn_cls: 0.01864  loss_rpn_loc: 0.06916  time: 0.3439  data_time: 0.0037  lr: 9e-06  max_mem: 3718M
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-0995ae8dd1df> in <module>
#      30 trainer = Trainer(cfg)
#      31 trainer.resume_or_load(resume=True)
# ---> 32 trainer.train()
#
# ~/detectron2_repo/detectron2/engine/defaults.py in train(self)
#     408             OrderedDict of results, if evaluation is enabled. Otherwise None.
#     409         """
# --> 410         super().train(self.start_iter, self.max_iter)
#     411         if len(self.cfg.TEST.EXPECTED_RESULTS) and comm.is_main_process():
#     412             assert hasattr(
#
# ~/detectron2_repo/detectron2/engine/train_loop.py in train(self, start_iter, max_iter)
#     140                 for self.iter in range(start_iter, max_iter):
#     141                     self.before_step()
# --> 142                     self.run_step()
#     143                     self.after_step()
#     144                 # self.iter == max_iter can be used by `after_train` to
#
# ~/detectron2_repo/detectron2/engine/train_loop.py in run_step(self)
#     233         If you want to do something with the losses, you can wrap the model.
#     234         """
# --> 235         loss_dict = self.model(data)
#     236         losses = sum(loss_dict.values())
#     237
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/detectron2_repo/detectron2/modeling/meta_arch/rcnn.py in forward(self, batched_inputs)
#     164             proposal_losses = {}
#     165
# --> 166         _, detector_losses = self.roi_heads(images, features, proposals, gt_instances)
#     167         if self.vis_period > 0:
#     168             storage = get_event_storage()
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/detectron2_repo/detectron2/modeling/roi_heads/roi_heads.py in forward(***failed resolving arguments***)
#     679         if self.training:
#     680             assert targets
# --> 681             proposals = self.label_and_sample_proposals(proposals, targets)
#     682         del targets
#     683
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# ~/detectron2_repo/detectron2/modeling/roi_heads/roi_heads.py in label_and_sample_proposals(self, proposals, targets)
#     287                 for (trg_name, trg_value) in targets_per_image.get_fields().items():
#     288                     if trg_name.startswith("gt_") and not proposals_per_image.has(trg_name):
# --> 289                         proposals_per_image.set(trg_name, trg_value[sampled_targets])
#     290             else:
#     291                 gt_boxes = Boxes(
#
# ~/detectron2_repo/detectron2/structures/masks.py in __getitem__(self, item)
#     349                 raise ValueError("Unsupported tensor dtype={} for indexing!".format(item.dtype))
#     350             selected_polygons = [self.polygons[i] for i in item]
# --> 351         return PolygonMasks(selected_polygons)
#     352
#     353     def __iter__(self) -> Iterator[List[np.ndarray]]:
#
# ~/detectron2_repo/detectron2/structures/masks.py in __init__(self, polygons)
#     283
#     284         self.polygons: List[List[np.ndarray]] = [
# --> 285             process_polygons(polygons_per_instance) for polygons_per_instance in polygons
#     286         ]
#     287
#
# ~/detectron2_repo/detectron2/structures/masks.py in <listcomp>(.0)
#     283
#     284         self.polygons: List[List[np.ndarray]] = [
# --> 285             process_polygons(polygons_per_instance) for polygons_per_instance in polygons
#     286         ]
#     287
#
# ~/detectron2_repo/detectron2/structures/masks.py in process_polygons(polygons_per_instance)
#     277             )
#     278             # transform the polygon to a tensor
# --> 279             polygons_per_instance = [_make_array(p) for p in polygons_per_instance]
#     280             for polygon in polygons_per_instance:
#     281                 assert len(polygon) % 2 == 0 and len(polygon) >= 6
#
# ~/detectron2_repo/detectron2/structures/masks.py in <listcomp>(.0)
#     277             )
#     278             # transform the polygon to a tensor
# --> 279             polygons_per_instance = [_make_array(p) for p in polygons_per_instance]
#     280             for polygon in polygons_per_instance:
#     281                 assert len(polygon) % 2 == 0 and len(polygon) >= 6
#
# ~/detectron2_repo/detectron2/structures/masks.py in _make_array(t)
#     267             if isinstance(t, torch.Tensor):
#     268                 t = t.cpu().numpy()
# --> 269             return np.asarray(t).astype("float64")
#     270
#     271         def process_polygons(
#
# KeyboardInterrupt:

# %%
from detectron2.utils.visualizer import ColorMode
import numpy as np
test_dataset_dicts = DatasetCatalog.get("weapons")
glock_test_metadata = MetadataCatalog.get("weapons")

# %%
smpl = np.random.choice(dataset_dicts, 1)
for d in smpl:
    img = cv2.imread(d["file_name"], cv2.IMREAD_UNCHANGED)#[:, :, ::-1]
    visualizer = Visualizer(img[:,:,:3], metadata=glock_metadata, scale=0.75)
    vis = visualizer.draw_dataset_dict(d)
    plt.figure()
    plt.imshow(vis.get_image())

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
confidence_threshold = 0.5
cfg.MODEL.RETINANET.SCORE_THRESH_TEST = confidence_threshold 
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = confidence_threshold 
#cfg.DATASETS.TEST = ("glock_show", )
predictor = DefaultPredictor(cfg)

# %%
from detectron2.utils.visualizer import ColorMode
from detectron2.utils.visualizer import Visualizer
for d in random.sample(dataset_dicts, 3):
    
    im = cv2.imread(d["file_name"])
    print(type(im), im.shape)
    #im = cv2.resize(im, (1131,597))
    print(type(im), im.shape)
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::1],
                   metadata=glock_metadata, 
                   scale=0.3)
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure()
    plt.imshow(v.get_image())

# %%
from detectron2.utils.visualizer import ColorMode
import os
glock_dir = "/glock/weapon_images_from_google"
glock_files = os.listdir(glock_dir)
for d in glock_files:
    d = os.path.join(glock_dir, d)
    im = cv2.imread(d)
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::1], scale=0.4, metadata=glock_metadata)
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure()
    plt.imshow(v.get_image())
